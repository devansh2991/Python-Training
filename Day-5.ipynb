# %% [markdown]
# <a href="https://colab.research.google.com/github/devansh2991/Python-Training/blob/main/Day-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
  x = int(input("Enter the table to print: "))
  for i in range(10,0,-1):
    print(i*x)
  y=input("Want to print another table: ")
  if(y.lower()!="Y" or y.lower()!="y"):
    pass
  if(y.lower()=="n"):
    break


def nameoffunction(a):
  c = a*a
  return c

nameoffunction(30)


def areaofcirlce(b):
  pi = 3.14
  return pi*(b**2)

areaofcirlce(3)


def great(name="demo"):
  print("Hello",name)

great()


sqr = lambda x,a,y: x**a+y
print(sqr(5,3,5))


def factorial(fact):
  if(fact==0):
    return 1
  return fact*factorial(fact-1)

factorial(6)


word='RaceCar'
word=word.lower()
st=word[-1::-1]
if(word==st):
  print("Palindrome")
else:
  print("Not Palindrome")

def calculation(a,b):
  print("Addition: ",a+b)
  print("Multiplication: ",a*b)
  print("Division: ",a/b)
  print("Subtraction: ",a-b)

calculation(8,2)
# Out:
# Enter the table to print: 5
# 50
# 45
# 40
# 35
# 30
# 25
# 20
# 15
# 10
# 5
# Want to print another table: n
# Hello demo
# 130
# Palindrome
# Addition:  10
# Multiplication:  16
# Division:  4.0
# Subtraction:  6
